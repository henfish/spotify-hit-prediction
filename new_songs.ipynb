# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Test set generation
# To generate a test set of new songs from years the original model has not seen (2020 onwards) we combine data from two additional Kaggle datasets. The first dataset has song attributes from 1 million tracks from Spotify. The second dataset, made in 2023, contains all the billboard hot 100 songs going back decades (making this list is the main criteria for hit vs flop). If a song is in the latter dataset, the "popularity" column is set to true; else false, only including those songs which are from 2020 and onward. The data is also preprocessed almost identically to the train and validation dataset.
#
# Sources:
# https://www.kaggle.com/datasets/amitanshjoshi/spotify-1million-tracks
# https://www.kaggle.com/datasets/dhruvildave/billboard-the-hot-100-songs

# %%
# read in the data
dataset = pd.read_csv('spotify_data.csv')
charts = pd.read_csv('charts.csv')

# %%
print(dataset.head())
# Out:
#    Unnamed: 0    artist_name        track_name                track_id  \
# 0           0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1           1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2           2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3           3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 4           4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
#
#    popularity  year     genre  danceability  energy  key  loudness  mode  \
# 0          68  2012  acoustic         0.483   0.303    4   -10.058     1
# 1          50  2012  acoustic         0.572   0.454    3   -10.286     1
# 2          57  2012  acoustic         0.409   0.234    3   -13.711     1
# 3          58  2012  acoustic         0.392   0.251   10    -9.845     1
# 4          54  2012  acoustic         0.430   0.791    6    -5.419     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0429        0.6940          0.000000    0.1150    0.139  133.406
# 1       0.0258        0.4770          0.000014    0.0974    0.515  140.182
# 2       0.0323        0.3380          0.000050    0.0895    0.145  139.832
# 3       0.0363        0.8070          0.000000    0.0797    0.508  204.961
# 4       0.0302        0.0726          0.019300    0.1100    0.217  171.864
#
#    duration_ms  time_signature
# 0       240166               3
# 1       216387               4
# 2       158960               4
# 3       304293               4
# 4       244320               4

# %%
print(charts.head())
# Out:
#          date  rank           song                         artist  last-week  \
# 0  2021-11-06     1     Easy On Me                          Adele        1.0
# 1  2021-11-06     2           Stay  The Kid LAROI & Justin Bieber        2.0
# 2  2021-11-06     3  Industry Baby        Lil Nas X & Jack Harlow        3.0
# 3  2021-11-06     4     Fancy Like                   Walker Hayes        4.0
# 4  2021-11-06     5     Bad Habits                     Ed Sheeran        5.0
#
#    peak-rank  weeks-on-board
# 0          1               3
# 1          1              16
# 2          1              14
# 3          3              19
# 4          2              18

# %%
print(dataset["genre"].unique())
# Out:
# ['acoustic' 'afrobeat' 'alt-rock' 'ambient' 'black-metal' 'blues'
#  'breakbeat' 'cantopop' 'chicago-house' 'chill' 'classical' 'club'
#  'comedy' 'country' 'dance' 'dancehall' 'death-metal' 'deep-house'
#  'detroit-techno' 'disco' 'drum-and-bass' 'dub' 'dubstep' 'edm' 'electro'
#  'electronic' 'emo' 'folk' 'forro' 'french' 'funk' 'garage' 'german'
#  'gospel' 'goth' 'grindcore' 'groove' 'guitar' 'hard-rock' 'hardcore'
#  'hardstyle' 'heavy-metal' 'hip-hop' 'house' 'indian' 'indie-pop'
#  'industrial' 'jazz' 'k-pop' 'metal' 'metalcore' 'minimal-techno'
#  'new-age' 'opera' 'party' 'piano' 'pop' 'pop-film' 'power-pop'
#  'progressive-house' 'psych-rock' 'punk' 'punk-rock' 'rock' 'rock-n-roll'
#  'romance' 'sad' 'salsa' 'samba' 'sertanejo' 'show-tunes'
#  'singer-songwriter' 'ska' 'sleep' 'songwriter' 'soul' 'spanish' 'swedish'
#  'tango' 'techno' 'trance' 'trip-hop']

# %% [markdown]
# Since the genre labels are slightly different than those in our original hit predictor dataset (a bit more fine grained), we consolidate a few genres together into larger labels (i.e. 'electronic' should be classified as edm).

# %%
# focus on the last 5 years of data, which have been unseen by the hit predictor model
dataset['years_to_2025'] = 2025 - dataset['year']
dataset = dataset[dataset["years_to_2025"] < 6]

# consolidate genres into the larger labels used in the hit predictor dataset 
dataset["genre"] = dataset["genre"].replace({'salsa': 'latin', 
                                             'samba': 'latin', 
                                             'hip-hop': 'rap',
                                             'soul': 'r&b',
                                             'funk': 'r&b',
                                             'electronic': 'edm'})
dataset = dataset[dataset["genre"].isin(['pop', 'r&b', 'rock', 'latin', 'rap', 'edm'])]

# same preprocessing applied to the hit predictor dataset
dataset['key_sin'] = np.sin(2 * np.pi * dataset['key'] / 12)
dataset['key_cos'] = np.cos(2 * np.pi * dataset['key'] / 12)
dataset['duration_s'] = dataset['duration_ms'].apply(lambda x: x / 1000) # convert ms to seconds

dataset.head()
# Out:
#         Unnamed: 0 artist_name                             track_name  \
# 439400      439400     BRONSON                               CALL OUT
# 439401      439401        Rezz                           Someone Else
# 439402      439402     Cadmium                             No Friends
# 439403      439403      Lane 8                                   Road
# 439404      439404   Over Easy  Don't Know You (Gabe Ceribelli Remix)
#
#                       track_id  popularity  year genre  danceability  energy  \
# 439400  4WIAD59mZw4c4j36fjTvFo          57  2020   edm         0.512   0.894
# 439401  4hR3hQKELrARHNZJ51D14s          58  2020   edm         0.644   0.349
# 439402  4U7G8dgUodMEVSv96QRcDb          60  2020   edm         0.771   0.644
# 439403  6kckNpuM5oXZrObLExRg6d          60  2020   edm         0.689   0.514
# 439404  04JNdQ6NMhrCivy2SmDzTT          56  2020   edm         0.596   0.834
#
#         key  ...  instrumentalness  liveness  valence    tempo  duration_ms  \
# 439400    0  ...          0.727000    0.1650   0.1800  105.024       179453
# 439401    2  ...          0.000034    0.1250   0.2460   94.971       198947
# 439402    4  ...          0.000007    0.0760   0.8310  145.029       235024
# 439403   11  ...          0.449000    0.0952   0.0963  121.985       238033
# 439404    7  ...          0.023500    0.1050   0.6740  123.970       156801
#
#         time_signature  years_to_2025   key_sin   key_cos  duration_s
# 439400               4              5  0.000000  1.000000     179.453
# 439401               4              5  0.866025  0.500000     198.947
# 439402               4              5  0.866025 -0.500000     235.024
# 439403               4              5 -0.500000  0.866025     238.033
# 439404               4              5 -0.500000 -0.866025     156.801
#
# [5 rows x 24 columns]

# %% [markdown]
# This is a custom function for checking if the song name and artist appears in the Billboard hot 100.

# %%
def is_in_charts(row):
    if row.name%100 == 0:
        print(f"Processing row {row.name}")
    return ((charts['artist'] == row['artist_name']) & (charts['song'] == row['track_name'])).any()
dataset['popularity'] = dataset.apply(is_in_charts, axis=1)
# Out:
# Processing row 439400
# Processing row 439500
# Processing row 439600
# Processing row 439700
# Processing row 439800
# Processing row 440200
# Processing row 440300
# Processing row 440400
# Processing row 440500
# Processing row 440600
# Processing row 440700
# Processing row 444100
# Processing row 444200
# Processing row 444300
# Processing row 444400
# Processing row 444500
# Processing row 444600
# Processing row 444700
# Processing row 444800
# Processing row 452900
# Processing row 453000
# Processing row 453100
# Processing row 453200
# Processing row 453300
# Processing row 453400
# Processing row 453500
# Processing row 453600
# Processing row 462000
# Processing row 462100
# Processing row 462200
# Processing row 462300
# Processing row 465500
# Processing row 467300
# Processing row 467400
# Processing row 467500
# Processing row 467600
# Processing row 467700
# Processing row 467800
# Processing row 467900
# Processing row 468000
# Processing row 468100
# Processing row 468200
# Processing row 468300
# Processing row 468400
# Processing row 468500
# Processing row 468600
# Processing row 468700
# Processing row 468800
# Processing row 468900
# Processing row 472600
# Processing row 472700
# Processing row 472800
# Processing row 472900
# Processing row 473000
# Processing row 493800
# Processing row 493900
# Processing row 494000
# Processing row 494100
# Processing row 494600
# Processing row 494700
# Processing row 494800
# Processing row 494900
# Processing row 495000
# Processing row 498400
# Processing row 498500
# Processing row 498600
# Processing row 498700
# Processing row 498800
# Processing row 498900
# Processing row 499000
# Processing row 499100
# Processing row 506700
# Processing row 506800
# Processing row 506900
# Processing row 507000
# Processing row 507100
# Processing row 507200
# Processing row 507300
# Processing row 507400
# Processing row 507500
# Processing row 515600
# Processing row 515700
# Processing row 515800
# Processing row 515900
# Processing row 519400
# Processing row 519500
# Processing row 521200
# Processing row 521300
# Processing row 521400
# Processing row 521500
# Processing row 521600
# Processing row 521700
# Processing row 521800
# Processing row 521900
# Processing row 522000
# Processing row 522100
# Processing row 522200
# Processing row 522300
# Processing row 522400
# Processing row 522500
# Processing row 522600
# Processing row 522700
# Processing row 526400
# Processing row 526500
# Processing row 526600
# Processing row 526700
# Processing row 526800
# Processing row 547400
# Processing row 547500
# Processing row 547600
# Processing row 547700
# Processing row 548100
# Processing row 548200
# Processing row 548300
# Processing row 548400
# Processing row 548500
# Processing row 551900
# Processing row 552000
# Processing row 552100
# Processing row 552200
# Processing row 552300
# Processing row 552400
# Processing row 552500
# Processing row 560200
# Processing row 560300
# Processing row 560400
# Processing row 560500
# Processing row 560600
# Processing row 560700
# Processing row 560800
# Processing row 560900
# Processing row 561000
# Processing row 569200
# Processing row 569300
# Processing row 569400
# Processing row 569500
# Processing row 573000
# Processing row 573100
# Processing row 575000
# Processing row 575100
# Processing row 575200
# Processing row 575300
# Processing row 575400
# Processing row 575500
# Processing row 575600
# Processing row 575700
# Processing row 575800
# Processing row 575900
# Processing row 576000
# Processing row 576100
# Processing row 576200
# Processing row 576300
# Processing row 576400
# Processing row 576500
# Processing row 580300
# Processing row 580400
# Processing row 580500
# Processing row 580600
# Processing row 580700
# Processing row 595200
# Processing row 595300
# Processing row 595600
# Processing row 595700
# Processing row 595800
# Processing row 595900
# Processing row 596000
# Processing row 598900
# Processing row 599000
# Processing row 599100
# Processing row 599200
# Processing row 599300
# Processing row 599400
# Processing row 605200
# Processing row 605300
# Processing row 605400
# Processing row 605500
# Processing row 612600
# Processing row 614800
# Processing row 614900
# Processing row 616300
# Processing row 616400
# Processing row 616500
# Processing row 616600
# Processing row 616700
# Processing row 616800
# Processing row 616900
# Processing row 617000
# Processing row 617100
# Processing row 617200
# Processing row 620000
# Processing row 620100
# Processing row 620200

# %%
dataset.drop(columns=['key', 'duration_ms', 'Unnamed: 0', 'track_id', 'year', 'track_name', 'artist_name'], inplace=True)

# %% [markdown]
# Our test dataset is imbalanced, with only about 1.3% of songs being hits, but it doesn't particularly matter since we're not training on it.

# %%
dataset['popularity'] = dataset['popularity'].astype(int)
dataset.describe()
# Out:
#          popularity  danceability        energy      loudness          mode  \
# count  18742.000000  18742.000000  18742.000000  18742.000000  18742.000000
# mean       0.012912      0.656593      0.659796     -7.341629      0.556824
# std        0.112899      0.139296      0.190526      3.315528      0.496774
# min        0.000000      0.000000      0.021300    -29.511000      0.000000
# 25%        0.000000      0.566000      0.537000     -8.929000      0.000000
# 50%        0.000000      0.667000      0.680000     -6.884000      1.000000
# 75%        0.000000      0.756000      0.807000     -5.187000      1.000000
# max        1.000000      0.985000      0.999000      3.795000      1.000000
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  18742.000000  18742.000000      18742.000000  18742.000000
# mean       0.110551      0.309014          0.119971      0.205339
# std        0.111299      0.281869          0.268313      0.178614
# min        0.000000      0.000002          0.000000      0.013400
# 25%        0.041100      0.048000          0.000000      0.097500
# 50%        0.059800      0.232000          0.000019      0.131000
# 75%        0.132000      0.528000          0.014500      0.260000
# max        0.958000      0.996000          0.994000      0.993000
#
#             valence         tempo  years_to_2025       key_sin       key_cos  \
# count  18742.000000  18742.000000   18742.000000  18742.000000  1.874200e+04
# mean       0.555688    121.591726       3.645129     -0.030245  5.018285e-02
# std        0.257109     29.168149       1.069206      0.661324  7.478444e-01
# min        0.000000      0.000000       2.000000     -1.000000 -1.000000e+00
# 25%        0.350000     97.206500       3.000000     -0.500000 -8.660254e-01
# 50%        0.573000    120.089500       4.000000      0.000000  6.123234e-17
# 75%        0.774000    140.002000       5.000000      0.500000  8.660254e-01
# max        0.988000    227.895000       5.000000      1.000000  1.000000e+00
#
#          duration_s
# count  18742.000000
# mean     219.549177
# std       82.407533
# min       18.919000
# 25%      168.475500
# 50%      207.190500
# 75%      255.662000
# max     1675.444000

# %%
dataset.to_csv("new_songs.csv", index=False)
